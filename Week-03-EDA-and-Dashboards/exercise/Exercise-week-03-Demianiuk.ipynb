# %% [markdown]
# # Exploratory Data Analysis Exercise
# * For this part we will be using the `data/cars.csv` dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline 
import scipy.stats as stats

# %% [markdown]
# # Load in the data
# * Use the file in the data folder called 'cars.csv'
# * Save it as a varible named 'df'
# * Display the first 5 rows of our dataframe

# %%
# Load data
df = pd.read_csv('/workspaces/ds-fall-2025-fri-1230/Week-03-EDA-and-Dashboards/data/cars.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0      Compact         Coupe           26        19        3916  46135
# 1      Compact   Convertible           28        19        3916  40650
# 2      Compact         Coupe           28        20        3916  36350
# 3      Compact         Coupe           28        18        3916  29450
# 4      Compact   Convertible           28        18        3916  34500

# %% [markdown]
# # Data clean up part 1.
#
# 1. Print the number of duplicate rows we have in our dataframe.
#
# 2. Modify our df to have all duplicate rows removed.
#
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %%
# 1. Print the number of duplicate rows we have in our dataframe.
duplicate_rows = df[df.duplicated()]
#df.shape[0]
#print(duplicate_rows)
duplicate_rows.shape[0]
# Out:
# 720

# %%
# Amount of all rows we have in our dataframe.
df.shape[0]
# Out:
# 11914

# %%
#  2. Modify our df to have all duplicate rows removed. 
df = df.drop_duplicates().copy()
df.shape[0]
# Out:
# 11194

# %%
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

duplicate_rows = df[df.duplicated()]
duplicate_rows.shape[0]
# Out:
# 0

# %% [markdown]
# # Data clean up part 2.
# * Which column has the most null values and how many null values does it have?
# * Print how long our dataframe is.
# * Remove any row that has a null value in it.
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

# %%
# * Which column has the most null values and how many null values does it have?

null_counts = df.isnull().sum()
#print(null_counts)
column_with_most_nulls = null_counts.idxmax()
print(column_with_most_nulls)
# Out:
# Engine HP

# %%
# * Print how long our dataframe is.
df.shape[0]
# Out:
# 11194

# %%
# * Remove any row that has a null value in it. 
df = df.dropna(how='any',axis=0) 
df.head(20)
# Out:
#     Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0    BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1    BMW    1 Series  2011  premium unleaded (required)      300.0
# 2    BMW    1 Series  2011  premium unleaded (required)      300.0
# 3    BMW    1 Series  2011  premium unleaded (required)      230.0
# 4    BMW    1 Series  2011  premium unleaded (required)      230.0
# 5    BMW    1 Series  2012  premium unleaded (required)      230.0
# 6    BMW    1 Series  2012  premium unleaded (required)      300.0
# 7    BMW    1 Series  2012  premium unleaded (required)      300.0
# 8    BMW    1 Series  2012  premium unleaded (required)      230.0
# 9    BMW    1 Series  2013  premium unleaded (required)      230.0
# 10   BMW    1 Series  2013  premium unleaded (required)      300.0
# 11   BMW    1 Series  2013  premium unleaded (required)      230.0
# 12   BMW    1 Series  2013  premium unleaded (required)      300.0
# 13   BMW    1 Series  2013  premium unleaded (required)      230.0
# 15   BMW    1 Series  2013  premium unleaded (required)      320.0
# 16   BMW    1 Series  2013  premium unleaded (required)      320.0
# 17  Audi         100  1992             regular unleaded      172.0
# 19  Audi         100  1992             regular unleaded      172.0
# 21  Audi         100  1992             regular unleaded      172.0
# 22  Audi         100  1993             regular unleaded      172.0
#
#     Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                6.0            MANUAL   rear wheel drive              2.0
# 1                6.0            MANUAL   rear wheel drive              2.0
# 2                6.0            MANUAL   rear wheel drive              2.0
# 3                6.0            MANUAL   rear wheel drive              2.0
# 4                6.0            MANUAL   rear wheel drive              2.0
# 5                6.0            MANUAL   rear wheel drive              2.0
# 6                6.0            MANUAL   rear wheel drive              2.0
# 7                6.0            MANUAL   rear wheel drive              2.0
# 8                6.0            MANUAL   rear wheel drive              2.0
# 9                6.0            MANUAL   rear wheel drive              2.0
# 10               6.0            MANUAL   rear wheel drive              2.0
# 11               6.0            MANUAL   rear wheel drive              2.0
# 12               6.0            MANUAL   rear wheel drive              2.0
# 13               6.0            MANUAL   rear wheel drive              2.0
# 15               6.0            MANUAL   rear wheel drive              2.0
# 16               6.0            MANUAL   rear wheel drive              2.0
# 17               6.0            MANUAL  front wheel drive              4.0
# 19               6.0         AUTOMATIC    all wheel drive              4.0
# 21               6.0            MANUAL    all wheel drive              4.0
# 22               6.0            MANUAL  front wheel drive              4.0
#
#    Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0       Compact         Coupe           26        19        3916  46135
# 1       Compact   Convertible           28        19        3916  40650
# 2       Compact         Coupe           28        20        3916  36350
# 3       Compact         Coupe           28        18        3916  29450
# 4       Compact   Convertible           28        18        3916  34500
# 5       Compact         Coupe           28        18        3916  31200
# 6       Compact   Convertible           26        17        3916  44100
# 7       Compact         Coupe           28        20        3916  39300
# 8       Compact   Convertible           28        18        3916  36900
# 9       Compact   Convertible           27        18        3916  37200
# 10      Compact         Coupe           28        20        3916  39600
# 11      Compact         Coupe           28        19        3916  31500
# 12      Compact   Convertible           28        19        3916  44400
# 13      Compact   Convertible           28        19        3916  37200
# 15      Compact   Convertible           25        18        3916  48250
# 16      Compact         Coupe           28        20        3916  43550
# 17      Midsize         Sedan           24        17        3105   2000
# 19      Midsize         Wagon           20        16        3105   2000
# 21      Midsize         Sedan           21        16        3105   2000
# 22      Midsize         Sedan           24        17        3105   2000

# %%
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

df.shape[0]
# Out:
# 11092

# %% [markdown]
# ### Make a bar chart that displays how many times each brand of car appears in this data.
# _Brand of car is the `Make` of the car._
# * You can achieve this by using value_counts or by a groupby.  Either is fine with me.

# %%
# Make a bar chart that displays how many times each brand of car appears in this data. 

#sns.scatterplot(x="Make", y="Year", data=df)
#condition = df['Make'].value_counts()
condition_df = df['Make'].value_counts().reset_index(name='Frequency')
#print(condition_df)
sns.barplot(x='Make', y='Frequency', data=condition_df)
plt.xticks(rotation=90, ha="right")  # 45° tilt, right alignment

plt.tight_layout()  # Adjust layout so labels don’t get cut off
plt.show()

# %% [markdown]
# # Make the cart more legible, by making it a horizontal bar chart and changing the figure size.  And also sort the values so the bar chart displays from lowest to highest.

# %%
# Make the cart more legible, by making it a horizontal bar chart, sorting the values, and changing the figure size.

condition_df = condition_df.sort_values(by="Frequency", ascending=True)

plt.figure(figsize=(12, 8))  # width=12, height=8 in inches
sns.barplot(x='Frequency', y='Make', data=condition_df)

plt.tight_layout()  # Adjust layout so labels don’t get cut off
plt.show()

# %% [markdown]
# # Make a timeline line chart in which the x-axis is the Year, and the y-axis is the mean MSRP.
# * you're going to have to do a `groupby` for this one for sure.
# * What's noticeable about it and what do you think the error is...

# %%
# Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.

msrp_year = df.groupby('Year')['MSRP'].mean().reset_index()

sns.lineplot(x = "Year", y = "MSRP", data = msrp_year)
# Out:
# <Axes: xlabel='Year', ylabel='MSRP'>

# %% [markdown]
# # It seems as though in the years before (and includig) 2000, they were counting in tens.
# Make a new column that is called `adjusted_price`, that contains all prices, however, for every year before 2000 make it 10x the original MSRP.
#    * Hint; you might need to use our old friend `np.where`

# %%
# Make a column where is 10 when year is less than 2000, else 1.

df["Price_adjuster"] = np.where(df["Year"] <= 2000, 10, 1)
df.head()
# Multiply the MSRP by the price adjuster.
df["MSRP"] = df["MSRP"] * df["Price_adjuster"]
df.head(100)
# Out:
#        Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0       BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1       BMW    1 Series  2011  premium unleaded (required)      300.0
# 2       BMW    1 Series  2011  premium unleaded (required)      300.0
# 3       BMW    1 Series  2011  premium unleaded (required)      230.0
# 4       BMW    1 Series  2011  premium unleaded (required)      230.0
# ..      ...         ...   ...                          ...        ...
# 103  Nissan       240SX  1998             regular unleaded      155.0
# 104   Volvo         240  1991             regular unleaded      114.0
# 105   Volvo         240  1991             regular unleaded      114.0
# 106   Volvo         240  1991             regular unleaded      114.0
# 107   Volvo         240  1992             regular unleaded      114.0
#
#      Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0                 6.0            MANUAL  rear wheel drive              2.0
# 1                 6.0            MANUAL  rear wheel drive              2.0
# 2                 6.0            MANUAL  rear wheel drive              2.0
# 3                 6.0            MANUAL  rear wheel drive              2.0
# 4                 6.0            MANUAL  rear wheel drive              2.0
# ..                ...               ...               ...              ...
# 103               4.0            MANUAL  rear wheel drive              2.0
# 104               4.0            MANUAL  rear wheel drive              4.0
# 105               4.0         AUTOMATIC  rear wheel drive              4.0
# 106               4.0            MANUAL  rear wheel drive              4.0
# 107               4.0            MANUAL  rear wheel drive              4.0
#
#     Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP  \
# 0        Compact         Coupe           26        19        3916  46135
# 1        Compact   Convertible           28        19        3916  40650
# 2        Compact         Coupe           28        20        3916  36350
# 3        Compact         Coupe           28        18        3916  29450
# 4        Compact   Convertible           28        18        3916  34500
# ..           ...           ...          ...       ...         ...    ...
# 103      Compact         Coupe           25        20        2009  41070
# 104      Midsize         Wagon           26        19         870  20000
# 105      Midsize         Wagon           23        18         870  20000
# 106      Midsize         Sedan           26        19         870  20000
# 107      Midsize         Sedan           26        19         870  20000
#
#      Price_adjuster
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 103              10
# 104              10
# 105              10
# 106              10
# 107              10
#
# [100 rows x 16 columns]

# %% [markdown]
# # Replot the new adjusted price.
# * Make the y-axis start at 0 and go up to 100,000

# %%
# Plot new prices
msrp_year = df.groupby('Year')['MSRP'].mean().reset_index()

sns.lineplot(x = "Year", y = "MSRP", data = msrp_year)
plt.ylim(0, 100000)

plt.show()

# %% [markdown]
# # Plot the relationship between Engine HP and highway MPG

# %%
# Plot the relationship between Engine HP and highway MPG

sns.regplot(x="Engine HP", y="highway MPG", data=df)
plt.xlabel("Engine HP")
plt.ylabel("Highway MPG")
plt.title("Engine HP vs Highway MPG")
plt.show()

# %%
### IF WE DIDN'T GET TO REMOVING OUTLIERS IN CLASS, THEN YOU CAN SKIP THIS SECTION
# Remove any outliers from Engine HP and highway MPG

# %% [markdown]
# # Replot the relationship between Engine HP and highway MPG

# %%
# Re-Plot the relationship between Engine HP and highway MPG

# %% [markdown]
# # Make a scatter plot of Engine HP vs highway MPG

# %%
# Make a scatter plot of Engine HP vs highway MPG
sns.scatterplot(x="Engine HP", y="highway MPG", data=df)
plt.xlabel("Engine HP")
plt.ylabel("Highway MPG")
plt.title("Engine HP vs Highway MPG")
plt.show()

# %% [markdown]
# # What does this plot tell you about how Engine HP affects highway MPG?

# %%
# What does this plot tell you about how Engine HP affects highway MPG?

print('The higher horse power the lower MPG.')
# Out:
# The higher horse power the lower MPG.

# %% [markdown]
# # Using a pairplot, display all of the linear relationship.
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %%
# Using a pairplot, display all of the linear relationship.
numeric_cols = ["Engine HP", "Engine Cylinders", "highway MPG", "city mpg", "Popularity", "MSRP"]

sns.pairplot(df[numeric_cols])
plt.show()

# %%
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %% [markdown]
# # Find which features actually have the strongest linear relationship using correlations.
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
# * __Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.__

# %%
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8

# %%
# Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.

print('Your answer here')
# Out:
# Your answer here

# %% [markdown]
# # [EXTRA CREDIT]
# * (EASY) In the column names, replace all the spaces with an underscore, and make them all lowercase as well.
#
# * (Easy) Learn more about cleaning data by following along in TA Georgios' tutorial in TA-Tips folder named `GI-Tips_1.ipynb`.
#
# * (Medium) Do the same vizualizations using bokeh by following along in TA Stevens tutorial in the TA-Tips folder named `SS-Tips.ipynb`.
#
#
# * (Medium) Learn how to remove outliers properly by following along in TA Georgios' tutorial in TA-Tips folder named `GI-Tips_2.ipynb`.
#
# * (Variable) Complete one or more of the [Extra-Extra credit](https://docs.google.com/document/d/1D99fY13cF3kzIiJILZ3fwzhOF73z_xPBNxxweMpBkOY/edit) items.
