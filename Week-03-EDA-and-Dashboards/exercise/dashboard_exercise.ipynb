# %%
import pandas as pd
import numpy as np
import seaborn as sns

df=pd.read_csv("../data/movie_ratings.csv")
df.head()

df=df.groupby("genres")["rating"].agg()
# Out:
#    user_id  movie_id  rating            timestamp  age gender  occupation  \
# 0      196       242       3  1997-12-04 15:55:49   49      M      writer
# 1      186       302       3  1998-04-04 19:22:22   39      F   executive
# 2       22       377       1  1997-11-07 07:18:36   25      M      writer
# 3      244        51       2  1997-11-27 05:02:03   28      M  technician
# 4      166       346       1  1998-02-02 05:33:16   47      M    educator
#
#   zip_code                       title    year  decade  \
# 0    55105                Kolya (1996)  1996.0  1990.0
# 1    00000    L.A. Confidential (1997)  1997.0  1990.0
# 2    40206         Heavyweights (1994)  1994.0  1990.0
# 3    80525  Legends of the Fall (1994)  1994.0  1990.0
# 4    55113         Jackie Brown (1997)  1997.0  1990.0
#
#                              genres  rating_year
# 0                            Comedy         1997
# 1  Crime|Film-Noir|Mystery|Thriller         1998
# ...
