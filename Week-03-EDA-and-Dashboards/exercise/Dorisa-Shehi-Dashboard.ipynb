# %%
import pandas as pd
import numpy as np
import altair as alt
alt.renderers.enable("png")
# Out:
# RendererRegistry.enable('png')

# %%
df = pd.read_csv('../data/movie_ratings.csv')

# %%
df.head()
# Out:
#    user_id  movie_id  rating            timestamp  age gender occupation  \
# 0      196       242       3  1997-12-04 15:55:49   49      M     writer
# 1      186       302       3  1998-04-04 19:22:22   39      F  executive
# 2      186       302       3  1998-04-04 19:22:22   39      F  executive
# 3      186       302       3  1998-04-04 19:22:22   39      F  executive
# 4      186       302       3  1998-04-04 19:22:22   39      F  executive
#
#   zip_code                     title    year  decade     genres  rating_year
# 0    55105              Kolya (1996)  1996.0  1990.0     Comedy         1997
# 1    00000  L.A. Confidential (1997)  1997.0  1990.0      Crime         1998
# 2    00000  L.A. Confidential (1997)  1997.0  1990.0  Film-Noir         1998
# 3    00000  L.A. Confidential (1997)  1997.0  1990.0    Mystery         1998
# 4    00000  L.A. Confidential (1997)  1997.0  1990.0   Thriller         1998

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212595 entries, 0 to 212594
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   user_id      212595 non-null  int64
#  1   movie_id     212595 non-null  int64
#  2   rating       212595 non-null  int64
#  3   timestamp    212595 non-null  object
#  4   age          212595 non-null  int64
#  5   gender       212595 non-null  object
#  6   occupation   212595 non-null  object
#  7   zip_code     212595 non-null  object
#  8   title        212595 non-null  object
#  9   year         212559 non-null  float64
#  10  decade       212559 non-null  float64
#  11  genres       212595 non-null  object
#  12  rating_year  212595 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 21.1+ MB

# %% [markdown]
# **Convert timestamp to datetime**

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
df.isnull().sum()
# Out:
# user_id         0
# movie_id        0
# rating          0
# timestamp       0
# age             0
# gender          0
# occupation      0
# zip_code        0
# title           0
# year           36
# decade         36
# genres          0
# rating_year     0
# dtype: int64

# %% [markdown]
# **What's the breakdown of genres for the movies that were rated?**

# %%
genres_df = df['genres'].value_counts().reset_index().rename({'index':'genre','genres':'count'}, axis = 1)

# %%
chart = alt.Chart(genres_df).mark_bar().encode(
    y=alt.Y('genre:N', sort=None, title='Genre'),
    x=alt.X('count:Q', title='Count'),
    color='genre:N',
    tooltip=['genre', 'count']
).properties(
    title='Genres Distribution',
    width=800,
    height=400
)

# %%
chart
# Out:
# ---------------------------------------------------------------------------
# DuplicateError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py:4033, in Chart.to_dict(self, validate, format, ignore, context)
#    4031     copy.data = core.InlineData(values=[{}])
#    4032     return super(Chart, copy).to_dict(**kwds)
# -> 4033 return super().to_dict(**kwds)
#
# File ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py:1994, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    1992 if not utils.is_undefined(original_data):
#    1993     try:
# -> 1994         data = nw.from_native(original_data, eager_or_interchange_only=True)
#    1995     except TypeError:
#    1996         # Non-narwhalifiable type supported by Altair, such as dict
#    1997         data = original_data
#
# File ~/.local/lib/python3.10/site-packages/narwhals/stable/v1/__init__.py:965, in from_native(native_object, strict, pass_through, eager_only, eager_or_interchange_only, series_only, allow_series, **kwds)
#     962     msg = f"from_native() got an unexpected keyword argument {next(iter(kwds))!r}"
#     963     raise TypeError(msg)
# --> 965 return _from_native_impl(  # type: ignore[no-any-return]
#     966     native_object,
#     967     pass_through=pass_through,
#     968     eager_only=eager_only,
#     969     eager_or_interchange_only=eager_or_interchange_only,
#     970     series_only=series_only,
#     971     allow_series=allow_series,
#     972     version=Version.V1,
#     973 )
#
# File ~/.local/lib/python3.10/site-packages/narwhals/translate.py:426, in _from_native_impl(native_object, pass_through, eager_only, eager_or_interchange_only, series_only, allow_series, version)
#     422             raise TypeError(msg)
#     423         return native_object
#     424     return (
#     425         version.namespace.from_native_object(native_object)
# --> 426         .compliant.from_native(native_object)
#     427         .to_narwhals()
#     428     )
#     430 # PyArrow
#     431 if is_native_arrow(native_object):
#
# File ~/.local/lib/python3.10/site-packages/narwhals/_compliant/namespace.py:165, in EagerNamespace.from_native(self, data)
#     161 def from_native(
#     162     self, data: NativeFrameT | NativeSeriesT | Any, /
#     163 ) -> EagerDataFrameT | EagerSeriesT:
#     164     if self._dataframe._is_native(data):
# --> 165         return self._dataframe.from_native(data, context=self)
#     166     if self._series._is_native(data):
#     167         return self._series.from_native(data, context=self)
#
# File ~/.local/lib/python3.10/site-packages/narwhals/_pandas_like/dataframe.py:186, in PandasLikeDataFrame.from_native(cls, data, context)
#     184 @classmethod
#     185 def from_native(cls, data: Any, /, *, context: _LimitedContext) -> Self:
# --> 186     return cls(
#     187         data,
#     188         implementation=context._implementation,
#     189         version=context._version,
#     190         validate_column_names=True,
#     191     )
#
# File ~/.local/lib/python3.10/site-packages/narwhals/_pandas_like/dataframe.py:114, in PandasLikeDataFrame.__init__(self, native_dataframe, implementation, version, validate_column_names, validate_backend_version)
#     112 self._version = version
#     113 if validate_column_names:
# --> 114     check_column_names_are_unique(native_dataframe.columns)
#     115 if validate_backend_version:
#     116     self._validate_backend_version()
#
# File ~/.local/lib/python3.10/site-packages/narwhals/_utils.py:1556, in check_column_names_are_unique(columns)
#    1554 msg = "".join(f"\n- '{k}' {v} times" for k, v in duplicates.items())
#    1555 msg = f"Expected unique column names, got:{msg}"
# -> 1556 raise DuplicateError(msg)
#
# DuplicateError: Expected unique column names, got:
# - 'count' 2 times
# alt.Chart(...)

# %% [markdown]
# **Which genres have the highest viewer satisfaction (highest ratings)?**

# %%
df['rating'].unique()
# Out:
# array([3, 1, 2, 4, 5])

# %% [markdown]
# **Strategies** \
# First Strategy is just caclulate average rating for each genre and find the one with the highest \
# Second Strategy is choose genres with highest percentage of max rating = 5.

# %%
genres_avg_rating = df.groupby(['genres']).agg({'rating':'mean'}).reset_index().sort_values(by= 'rating', ascending=False)

# %%
chart = alt.Chart(genres_avg_rating).mark_bar().encode(
    x=alt.X('genres:N', sort='-y'),   # sort bars by count
    y=alt.Y('rating:Q'),
    color=alt.Color('genres:N', legend=None),  # distinct colors per brand
    tooltip=['genres', 'rating']
).properties(
    title="Best Genre based on average rating",
    width=900,
    height=200
)

chart.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py:3682, in TopLevelMixin._repr_mimebundle_(self, *args, **kwds)
#    3680 else:
#    3681     if renderer := renderers.get():
# -> 3682         return renderer(dct)
#
# File ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/display.py:67, in png_renderer(spec, **metadata)
#      64 def png_renderer(spec: dict, **metadata) -> dict[str, bytes]:
#      65     # To get proper return value type, would need to write complex
#      66     # overload signatures for spec_to_mimebundle based on `format`
# ---> 67     return spec_to_mimebundle(  # type: ignore[return-value]
#      68         spec,
#      69         format="png",
#      70         mode="vega-lite",
#      71         vega_version=VEGA_VERSION,
#      72         vegaembed_version=VEGAEMBED_VERSION,
#      73         vegalite_version=VEGALITE_VERSION,
#      74         **metadata,
#      75     )
#
# File ~/.local/lib/python3.10/site-packages/altair/utils/mimebundle.py:141, in spec_to_mimebundle(spec, format, mode, vega_version, vegaembed_version, vegalite_version, embed_options, engine, **kwargs)
#     138 embed_options = preprocess_embed_options(final_embed_options)
#     140 if format in {"png", "svg", "pdf", "vega"}:
# --> 141     return _spec_to_mimebundle_with_engine(
#     142         spec,
#     143         cast(Literal["png", "svg", "pdf", "vega"], format),
#     144         internal_mode,
#     145         engine=engine,
#     146         format_locale=embed_options.get("formatLocale", None),
#     147         time_format_locale=embed_options.get("timeFormatLocale", None),
#     148         **kwargs,
#     149     )
#     150 elif format == "html":
#     151     html = spec_to_html(
#     152         spec,
#     153         mode=internal_mode,
#    (...)
#     158         **kwargs,
#     159     )
#
# File ~/.local/lib/python3.10/site-packages/altair/utils/mimebundle.py:211, in _spec_to_mimebundle_with_engine(spec, format, mode, format_locale, time_format_locale, **kwargs)
#     208 # Normalize the engine string (if any) by lower casing
#     209 # and removing underscores and hyphens
#     210 engine = kwargs.pop("engine", None)
# --> 211 normalized_engine = _validate_normalize_engine(engine, format)
#     213 if normalized_engine == "vlconvert":
#     214     vlc = import_vl_convert()
#
# File ~/.local/lib/python3.10/site-packages/altair/utils/mimebundle.py:330, in _validate_normalize_engine(engine, format)
#     325     else:
#     326         msg = (
#     327             f"Saving charts in {format!r} format requires the vl-convert-python package: "
#     328             "see https://altair-viz.github.io/user_guide/saving_charts.html#png-svg-and-pdf-format"
#     329         )
# --> 330         raise ValueError(msg)
#     331 else:
#     332     msg = f"Invalid conversion engine {engine!r}. Expected vl-convert"
#
# ValueError: Saving charts in 'png' format requires the vl-convert-python package: see https://altair-viz.github.io/user_guide/saving_charts.html#png-svg-and-pdf-format
# alt.Chart(...)

# %% [markdown]
# **second approach**

# %%
# Step 1: count total ratings per genre
total_counts = df.groupby("genres")["rating"].count()
# Step 2: count only 5-star ratings per genre
five_star_counts = df[df["rating"] == 5].groupby("genres")["rating"].count()
# Step 3: combine
best_genres = pd.DataFrame({
    "total_ratings": total_counts,
    "five_star_count": five_star_counts
}).fillna(0).reset_index()

best_genres['percentage'] = round(best_genres['five_star_count'] / best_genres['total_ratings'],2)
best_genres.sort_values(by = 'percentage', ascending = False)
# Out:
#          genres  total_ratings  five_star_count  percentage
# 9     Film-Noir           1733              560        0.32
# 16          War           9398             2914        0.31
# 6   Documentary            758              209        0.28
# 7         Drama          39895             9997        0.25
# 5         Crime           8055             1963        0.24
# 13      Romance          19461             4559        0.23
# 14       Sci-Fi          12730             2914        0.23
# 12      Mystery           5245             1225        0.23
# 2     Animation           3605              796        0.22
# 17      Western           1854              394        0.21
# 1     Adventure          13753             2903        0.21
# 11      Musical           4954             1050        0.21
# 15     Thriller          21872             4312        0.20
# 0        Action          25589             5103        0.20
# 4        Comedy          29832             5224        0.18
# 3      Children           7182             1217        0.17
# 10       Horror           5317              877        0.16
# 8       Fantasy           1352              176        0.13
# 18      unknown             10                1        0.10

# %%
chart = alt.Chart(best_genres).mark_bar().encode(
    x=alt.X('genres:N', sort='-y'),   # sort bars by count
    y=alt.Y('percentage:Q'),
    color=alt.Color('genres:N', legend=None),  # distinct colors per brand
    tooltip=['genres', 'percentage']
).properties(
    title="Percentage of 5 star  ratings",
    width=900,
    height=200
)

chart.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/api.py:3682, in TopLevelMixin._repr_mimebundle_(self, *args, **kwds)
#    3680 else:
#    3681     if renderer := renderers.get():
# -> 3682         return renderer(dct)
#
# File ~/.local/lib/python3.10/site-packages/altair/vegalite/v5/display.py:67, in png_renderer(spec, **metadata)
#      64 def png_renderer(spec: dict, **metadata) -> dict[str, bytes]:
#      65     # To get proper return value type, would need to write complex
#      66     # overload signatures for spec_to_mimebundle based on `format`
# ---> 67     return spec_to_mimebundle(  # type: ignore[return-value]
#      68         spec,
#      69         format="png",
#      70         mode="vega-lite",
#      71         vega_version=VEGA_VERSION,
#      72         vegaembed_version=VEGAEMBED_VERSION,
#      73         vegalite_version=VEGALITE_VERSION,
#      74         **metadata,
#      75     )
#
# File ~/.local/lib/python3.10/site-packages/altair/utils/mimebundle.py:141, in spec_to_mimebundle(spec, format, mode, vega_version, vegaembed_version, vegalite_version, embed_options, engine, **kwargs)
#     138 embed_options = preprocess_embed_options(final_embed_options)
#     140 if format in {"png", "svg", "pdf", "vega"}:
# --> 141     return _spec_to_mimebundle_with_engine(
#     142         spec,
#     143         cast(Literal["png", "svg", "pdf", "vega"], format),
#     144         internal_mode,
#     145         engine=engine,
#     146         format_locale=embed_options.get("formatLocale", None),
#     147         time_format_locale=embed_options.get("timeFormatLocale", None),
#     148         **kwargs,
#     149     )
#     150 elif format == "html":
#     151     html = spec_to_html(
#     152         spec,
#     153         mode=internal_mode,
#    (...)
#     158         **kwargs,
#     159     )
#
# File ~/.local/lib/python3.10/site-packages/altair/utils/mimebundle.py:211, in _spec_to_mimebundle_with_engine(spec, format, mode, format_locale, time_format_locale, **kwargs)
#     208 # Normalize the engine string (if any) by lower casing
#     209 # and removing underscores and hyphens
#     210 engine = kwargs.pop("engine", None)
# --> 211 normalized_engine = _validate_normalize_engine(engine, format)
#     213 if normalized_engine == "vlconvert":
#     214     vlc = import_vl_convert()
#
# File ~/.local/lib/python3.10/site-packages/altair/utils/mimebundle.py:330, in _validate_normalize_engine(engine, format)
#     325     else:
#     326         msg = (
#     327             f"Saving charts in {format!r} format requires the vl-convert-python package: "
#     328             "see https://altair-viz.github.io/user_guide/saving_charts.html#png-svg-and-pdf-format"
#     329         )
# --> 330         raise ValueError(msg)
#     331 else:
#     332     msg = f"Invalid conversion engine {engine!r}. Expected vl-convert"
#
# ValueError: Saving charts in 'png' format requires the vl-convert-python package: see https://altair-viz.github.io/user_guide/saving_charts.html#png-svg-and-pdf-format
# alt.Chart(...)

# %% [markdown]
# **How does mean rating change across movie release years?**

# %%
df["year_month"] = df["timestamp"].dt.to_period("M").astype(str)

# %%
back_to_future = df[df['title'] == "Back to the Future (1985)"]

# %%
time_rating = back_to_future.groupby('year_month').agg({'rating':'mean'}).reset_index().sort_values(by = 'year_month', ascending = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 time_rating = back_to_future.groupby('year_month').agg({'rating':'mean'}).reset_index().sort_values(by = 'year_month', ascending = True)
#
# NameError: name 'back_to_future' is not defined

# %%
chart = (
    alt.Chart(time_rating)
    .mark_line(point=True)
    .encode(
        x=alt.X("year_month:O", title="Year-Month"),  # use Ordinal (O) instead of Temporal (T)
        y=alt.Y("rating:Q", title="Average Rating"),
        tooltip=["year_month", "rating:Q"]
    )
    .properties(
        title="Average Movie Ratings Over Time",
        width=600,
        height=400
    )
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# **What are the 5 best-rated movies that have at least 50 ratings? At least 150 ratings?**

# %%
best_rated_movs = (
    df.groupby("title")
    .filter(lambda x: len(x) >= 50)
    .groupby("title")["rating"]
    .mean()
    .sort_values( ascending=False)
).reset_index()

# %%
best_rated_movs[:5]
# Out:
#                                                title    rating
# 0                              Close Shave, A (1995)  4.491071
# 1                            Schindler's List (1993)  4.466443
# 2                         Wrong Trousers, The (1993)  4.466102
# 3                                  Casablanca (1942)  4.456790
# 4  Wallace & Gromit: The Best of Aardman Animatio...  4.447761

# %%
best_rated_movs = (
    df.groupby("title")
    .filter(lambda x: len(x) >= 150)
    .groupby("title")["rating"]
    .mean()
    .sort_values( ascending=False)
).reset_index()

# %%
best_rated_movs[:5]
# Out:
#                               title    rating
# 0             Close Shave, A (1995)  4.491071
# 1           Schindler's List (1993)  4.466443
# 2        Wrong Trousers, The (1993)  4.466102
# 3                 Casablanca (1942)  4.456790
# 4  Shawshank Redemption, The (1994)  4.445230

# %% [markdown]
# **For each genre, how does the rating change as viewer age increases?**

# %%
age_rating = df.groupby(['genres','age']).agg({'rating':'mean'}).reset_index()

# %%
age_rating
# Out:
#        genres  age    rating
# 0      Action    7  3.611111
# 1      Action   10  4.000000
# 2      Action   11  3.076923
# 3      Action   13  3.493421
# 4      Action   14  3.593220
# ...       ...  ...       ...
# 1057  unknown   26  2.500000
# 1058  unknown   29  3.000000
# 1059  unknown   33  4.000000
# 1060  unknown   34  1.000000
# 1061  unknown   38  4.000000
#
# [1062 rows x 3 columns]

# %%
action_genre = age_rating[age_rating['genres'] == 'Action']

# %%
action_genre
# Out:
#     genres  age    rating
# 0   Action    7  3.611111
# 1   Action   10  4.000000
# 2   Action   11  3.076923
# 3   Action   13  3.493421
# 4   Action   14  3.593220
# ..     ...  ...       ...
# 56  Action   66  3.000000
# 57  Action   68  3.166667
# 58  Action   69  3.730769
# 59  Action   70  3.565217
# 60  Action   73  4.000000
#
# [61 rows x 3 columns]

# %%
from IPython.display import display

for genre in age_rating['genres'].unique()[:5]: # limited to 5 cause there a lof of them
    selected_genre = age_rating[age_rating['genres'] == genre]
    chart = (
        alt.Chart(selected_genre)
        .mark_line(point=True)
        .encode(
            x=alt.X("age:O", title="Age"),
            y=alt.Y("rating:Q", title="Average Rating"),
            tooltip=["age", "rating:Q"]
        )
        .properties(
            title=genre,
            width=400,
            height=200
        )
    )

    display(chart)
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %% [markdown]
# **Plot number of ratings vs mean rating per genre. Is there a correlation between the volume of ratings and mean rating?**

# %%
count_vs_mean = df.groupby('title').agg(
     rating_count = ("rating","count"),
     rating_mean  = ("rating","mean")
).reset_index()
count_vs_mean["rating_mean"] = round(count_vs_mean["rating_mean"],1)

# %%
count_vs_mean
# Out:
#                                       title  rating_count  rating_mean
# 0                 'Til There Was You (1997)            18          2.3
# 1                              1-900 (1994)             5          2.6
# 2                     101 Dalmatians (1996)           218          2.9
# 3                       12 Angry Men (1957)           125          4.3
# 4                                187 (1997)            41          3.0
# ...                                     ...           ...          ...
# 1659                   Young Guns II (1990)           132          2.8
# 1660  Young Poisoner's Handbook, The (1995)            41          3.3
# 1661                Zeus and Roxanne (1997)             6          2.2
# 1662                                unknown             9          3.4
# 1663     Á köldum klaka (Cold Fever) (1994)             2          3.0
#
# [1664 rows x 3 columns]

# %%
correlation = count_vs_mean[["rating_count", "rating_mean"]].corr()
print(correlation)
# Out:
#               rating_count  rating_mean
# rating_count      1.000000     0.339318
# rating_mean       0.339318     1.000000

# %% [markdown]
# positive correlation but not very high

# %%
dirty_df = pd.read_csv("../data/movie_ratings_EC.csv")

# %%
dirty_df['genres']
# Out:
# 0                                  Comedy
# 1        Crime|Film-Noir|Mystery|Thriller
# 2                         Children|Comedy
# 3               Drama|Romance|War|Western
# 4                             Crime|Drama
#                        ...
# 99995                              Comedy
# 99996                       Comedy|Sci-Fi
# 99997                            Thriller
# 99998                     Children|Comedy
# 99999                             Western
# Name: genres, Length: 100000, dtype: object

# %%
df_exploded = df.explode("genres")
#

# %%
df_exploded['genres'].unique()
# Out:
# array(['Comedy', 'Crime', 'Film-Noir', 'Mystery', 'Thriller', 'Children',
#        'Drama', 'Romance', 'War', 'Western', 'Sci-Fi', 'Action',
#        'Adventure', 'Musical', 'Documentary', 'Animation', 'Horror',
#        'Fantasy', 'unknown'], dtype=object)

# %% [markdown]
# **WOW**
