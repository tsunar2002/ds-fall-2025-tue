# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.

import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.shape
# Out:
# (125, 61)

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.

df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
#  12  cuisine                       108 non-null    float64
#  13  diet_current                  124 non-null    object
#  14  diet_current_coded            125 non-null    int64
#  15  drink                         123 non-null    float64
#  16  eating_changes                122 non-null    object
#  17  eating_changes_coded          125 non-null    int64
#  18  eating_changes_coded1         125 non-null    int64
#  19  eating_out                    125 non-null    int64
#  20  employment                    116 non-null    float64
#  21  ethnic_food                   125 non-null    int64
#  22  exercise                      112 non-null    float64
#  23  father_education              124 non-null    float64
#  24  father_profession             122 non-null    object
#  25  fav_cuisine                   123 non-null    object
#  26  fav_cuisine_coded             125 non-null    int64
#  27  fav_food                      123 non-null    float64
#  28  food_childhood                124 non-null    object
#  29  fries                         125 non-null    int64
#  30  fruit_day                     125 non-null    int64
#  31  grade_level                   125 non-null    int64
#  32  greek_food                    125 non-null    int64
#  33  healthy_feeling               125 non-null    int64
#  34  healthy_meal                  124 non-null    object
#  35  ideal_diet                    124 non-null    object
#  36  ideal_diet_coded              125 non-null    int64
#  37  income                        124 non-null    float64
#  38  indian_food                   125 non-null    int64
#  39  italian_food                  125 non-null    int64
#  40  life_rewarding                124 non-null    float64
#  41  marital_status                124 non-null    float64
#  42  meals_dinner_friend           122 non-null    object
#  43  mother_education              122 non-null    float64
#  44  mother_profession             123 non-null    object
#  45  nutritional_check             125 non-null    int64
#  46  on_off_campus                 124 non-null    float64
#  47  parents_cook                  125 non-null    int64
#  48  pay_meal_out                  125 non-null    int64
#  49  persian_food                  124 non-null    float64
#  50  self_perception_weight        124 non-null    float64
#  51  soup                          124 non-null    float64
#  52  sports                        123 non-null    float64
#  53  thai_food                     125 non-null    int64
#  54  tortilla_calories             124 non-null    float64
#  55  turkey_calories               125 non-null    int64
#  56  type_sports                   99 non-null     object
#  57  veggies_day                   125 non-null    int64
#  58  vitamins                      125 non-null    int64
#  59  waffle_calories               125 non-null    int64
#  60  weight                        123 non-null    object
# dtypes: float64(20), int64(27), object(14)
# memory usage: 59.7+ KB

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.

df_food = df_food[['calories_day', 'weight', 'Gender']]
df_food
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

nan_count = df_food.isna().sum()

nan_count
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.

df_food = df_food.dropna()

df_food
# Out:
#      calories_day                    weight  Gender
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# 5             3.0                       190       1
# ..            ...                       ...     ...
# 118           3.0                       140       1
# 119           3.0                       185       2
# 120           4.0                       156       1
# 121           2.0                       180       1
# 123           4.0                       135       2
#
# [104 rows x 3 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.

for col in df_food:
    df_food[col] = pd.to_numeric(df_food[col], errors='coerce')
df_food = df_food.dropna()

df_food
# Out:
# /tmp/ipykernel_2315/4099765674.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food[col] = pd.to_numeric(df_food[col], errors='coerce')
#      calories_day  weight  Gender
# 1             3.0   155.0       1
# 4             2.0   190.0       1
# 5             3.0   190.0       1
# 6             3.0   180.0       2
# 7             3.0   137.0       1
# ..            ...     ...     ...
# 118           3.0   140.0       1
# 119           3.0   185.0       2
# 120           4.0   156.0       1
# 121           2.0   180.0       1
# 123           4.0   135.0       2
#
# [101 rows x 3 columns]

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
save_as = '../data/edited_food.csv'
df_food.to_csv(save_as, index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).

df_salary = pd.read_csv('../data/manager_salary.tsv', sep='	')
df_salary
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# 0            Research and Instruction Librarian
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 28057                              Veterinarian
# 28058                         Systems Architect
# 28059                 Risk Management Associate
# 28060                                        IT
# 28061                    Clinical physiologist
#
#       If your job title needs additional context, please clarify here:  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28057                                                NaN
# 28058                                                NaN
# 28059                                                NaN
# 28060                                                NaN
# 28061                                                NaN
#
#       What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  \
# 0                                                 55,000
# 1                                                 54,600
# 2                                                 34,000
# 3                                                 62,000
# 4                                                 60,000
# ...                                                  ...
# 28057                                             135000
# 28058                                             109000
# 28059                                               1200
# 28060                                               1700
# 28061                                            1200000
#
#        How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.  \
# 0                                                    0.0
# 1                                                 4000.0
# 2                                                    NaN
# 3                                                 3000.0
# 4                                                 7000.0
# ...                                                  ...
# 28057                                                NaN
# 28058                                                NaN
# 28059                                                0.0
# 28060                                               10.0
# 28061                                                NaN
#
#       Please indicate the currency  \
# 0                              USD
# 1                              GBP
# 2                              USD
# 3                              USD
# 4                              USD
# ...                            ...
# 28057                          USD
# 28058                          USD
# 28059                          USD
# 28060                          USD
# 28061                        Other
#
#       If "Other," please indicate the currency here:   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 28057                                             NaN
# 28058                                             NaN
# 28059                                             NaN
# 28060                                             NaN
# 28061                                             NGN
#
#       If your income needs additional context, please provide it here:  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28057                                                NaN
# 28058                                                NaN
# 28059                                                NaN
# 28060                                                NaN
# 28061                                                NaN
#
#       What country do you work in?  \
# 0                    United States
# 1                   United Kingdom
# 2                               US
# 3                              USA
# 4                               US
# ...                            ...
# 28057               United States
# 28058                          USA
# 28059                      Myanmar
# 28060                        Burma
# 28061                     Nigeria
#
#       If you're in the U.S., what state do you work in?  \
# 0                                         Massachusetts
# 1                                                   NaN
# 2                                             Tennessee
# 3                                             Wisconsin
# 4                                        South Carolina
# ...                                                 ...
# 28057                                          Missouri
# 28058                                           Georgia
# 28059                                          Colorado
# 28060                                               NaN
# 28061                                               NaN
#
#       What city do you work in?  \
# 0                        Boston
# 1                     Cambridge
# 2                   Chattanooga
# 3                     Milwaukee
# 4                    Greenville
# ...                         ...
# 28057               Wentzville
# 28058                   Atlanta
# 28059                    Yangon
# 28060                    Yangon
# 28061                     Lagos
#
#       How many years of professional work experience do you have overall?  \
# 0                                              5-7 years
# 1                                           8 - 10 years
# 2                                            2 - 4 years
# 3                                           8 - 10 years
# 4                                           8 - 10 years
# ...                                                  ...
# 28057                                      11 - 20 years
# 28058                                          5-7 years
# 28059                                        2 - 4 years
# 28060                                        2 - 4 years
# 28061                                        2 - 4 years
#
#       How many years of professional work experience do you have in your field?  \
# 0                                              5-7 years
# 1                                              5-7 years
# 2                                            2 - 4 years
# 3                                              5-7 years
# 4                                              5-7 years
# ...                                                  ...
# 28057                                      11 - 20 years
# 28058                                          5-7 years
# 28059                                        2 - 4 years
# 28060                                     1 year or less
# 28061                                        2 - 4 years
#
#       What is your highest level of education completed? What is your gender?  \
# 0                                        Master's degree                Woman
# 1                                         College degree           Non-binary
# 2                                         College degree                Woman
# 3                                         College degree                Woman
# 4                                         College degree                Woman
# ...                                                  ...                  ...
# 28057                 Professional degree (MD, JD, etc.)                Woman
# 28058                                     College degree                  Man
# 28059                                       Some college                  Man
# 28060                                       Some college                  Man
# 28061                                     College degree                Woman
#
#       What is your race? (Choose all that apply.)
# 0                                           White
# 1                                           White
# 2                                           White
# 3                                           White
# 4                                           White
# ...                                           ...
# 28057                                       White
# 28058                                       White
# 28059                     Asian or Asian American
# 28060                     Asian or Asian American
# 28061                   Black or African American
#
# [28062 rows x 18 columns]

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.

df_salary.shape
# Out:
# (28062, 18)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                             28062 non-null  object
#  1   How old are you?                                                                                                                                                                                                                      28062 non-null  object
#  2   What industry do you work in?                                                                                                                                                                                                         27988 non-null  object
#  3   Job title                                                                                                                                                                                                                             28061 non-null  object
#  4   If your job title needs additional context, please clarify here:                                                                                                                                                                      7262 non-null   object
#  5   What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  28062 non-null  object
#  6   How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                        20766 non-null  float64
#  7   Please indicate the currency                                                                                                                                                                                                          28062 non-null  object
#  8   If "Other," please indicate the currency here:                                                                                                                                                                                        206 non-null    object
#  9   If your income needs additional context, please provide it here:                                                                                                                                                                      3042 non-null   object
#  10  What country do you work in?                                                                                                                                                                                                          28062 non-null  object
#  11  If you're in the U.S., what state do you work in?                                                                                                                                                                                     23039 non-null  object
#  12  What city do you work in?                                                                                                                                                                                                             27980 non-null  object
#  13  How many years of professional work experience do you have overall?                                                                                                                                                                   28062 non-null  object
#  14  How many years of professional work experience do you have in your field?                                                                                                                                                             28062 non-null  object
#  15  What is your highest level of education completed?                                                                                                                                                                                    27840 non-null  object
#  16  What is your gender?                                                                                                                                                                                                                  27891 non-null  object
#  17  What is your race? (Choose all that apply.)                                                                                                                                                                                           27885 non-null  object
# dtypes: float64(1), object(17)
# memory usage: 3.9+ MB

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

names = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed', 'gender', 'race']

df_salary.columns = names

df_salary
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                    Health care
#
#                                           title title_context   salary  \
# 0            Research and Instruction Librarian           NaN   55,000
# 1      Change & Internal Communications Manager           NaN   54,600
# 2                          Marketing Specialist           NaN   34,000
# 3                               Program Manager           NaN   62,000
# 4                            Accounting Manager           NaN   60,000
# ...                                         ...           ...      ...
# 28057                              Veterinarian           NaN   135000
# 28058                         Systems Architect           NaN   109000
# 28059                 Risk Management Associate           NaN     1200
# 28060                                        IT           NaN     1700
# 28061                    Clinical physiologist            NaN  1200000
#
#        additional_compensation currency other_currency salary_context  \
# 0                          0.0      USD            NaN            NaN
# 1                       4000.0      GBP            NaN            NaN
# 2                          NaN      USD            NaN            NaN
# 3                       3000.0      USD            NaN            NaN
# 4                       7000.0      USD            NaN            NaN
# ...                        ...      ...            ...            ...
# 28057                      NaN      USD            NaN            NaN
# 28058                      NaN      USD            NaN            NaN
# 28059                      0.0      USD            NaN            NaN
# 28060                     10.0      USD            NaN            NaN
# 28061                      NaN    Other            NGN            NaN
#
#               country           state         city      total_yoe  \
# 0       United States   Massachusetts       Boston      5-7 years
# 1      United Kingdom             NaN    Cambridge   8 - 10 years
# 2                  US       Tennessee  Chattanooga    2 - 4 years
# 3                 USA       Wisconsin    Milwaukee   8 - 10 years
# 4                  US  South Carolina   Greenville   8 - 10 years
# ...               ...             ...          ...            ...
# 28057  United States         Missouri  Wentzville   11 - 20 years
# 28058             USA         Georgia      Atlanta      5-7 years
# 28059         Myanmar        Colorado       Yangon    2 - 4 years
# 28060           Burma             NaN       Yangon    2 - 4 years
# 28061        Nigeria              NaN        Lagos    2 - 4 years
#
#             field_yoe         highest_education_completed      gender  \
# 0           5-7 years                     Master's degree       Woman
# 1           5-7 years                      College degree  Non-binary
# 2         2 - 4 years                      College degree       Woman
# 3           5-7 years                      College degree       Woman
# 4           5-7 years                      College degree       Woman
# ...               ...                                 ...         ...
# 28057   11 - 20 years  Professional degree (MD, JD, etc.)       Woman
# 28058       5-7 years                      College degree         Man
# 28059     2 - 4 years                        Some college         Man
# 28060  1 year or less                        Some college         Man
# 28061     2 - 4 years                      College degree       Woman
#
#                             race
# 0                          White
# 1                          White
# 2                          White
# 3                          White
# 4                          White
# ...                          ...
# 28057                      White
# 28058                      White
# 28059    Asian or Asian American
# 28060    Asian or Asian American
# 28061  Black or African American
#
# [28062 rows x 18 columns]

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.

df_salary.industry.value_counts()
# Out:
# industry
# Computing or Tech                        4699
# Education (Higher Education)             2464
# Nonprofits                               2419
# Health care                              1896
# Government and Public Administration     1889
#                                          ...
# Warehousing                                 1
# Education (Early Childhood Education)       1
# SAAS                                        1
# Health and Safety                           1
# Aerospace Manufacturing                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)

condition_1 = df_salary['industry'] != 'Computing or Tech'

no_tech = df_salary[condition_1]

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 

no_tech.industry.value_counts()
# Out:
# industry
# Education (Higher Education)             2464
# Nonprofits                               2419
# Health care                              1896
# Government and Public Administration     1889
# Accounting, Banking & Finance            1809
#                                          ...
# Warehousing                                 1
# Education (Early Childhood Education)       1
# SAAS                                        1
# Health and Safety                           1
# Aerospace Manufacturing                     1
# Name: count, Length: 1218, dtype: int64

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!

condition_2 = df_salary['currency'] == 'USD'

usd = df_salary[condition_2]

usd
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28052   7/3/2024 14:02:01  25-34              Computing or Tech
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
#
#                                         title title_context  salary  \
# 0          Research and Instruction Librarian           NaN  55,000
# 2                        Marketing Specialist           NaN  34,000
# 3                             Program Manager           NaN  62,000
# 4                          Accounting Manager           NaN  60,000
# 5              Scholarly Publishing Librarian           NaN  62,000
# ...                                       ...           ...     ...
# 28052  Senior Global Public Relations Manager           NaN  144000
# 28057                            Veterinarian           NaN  135000
# 28058                       Systems Architect           NaN  109000
# 28059               Risk Management Associate           NaN    1200
# 28060                                      IT           NaN    1700
#
#        additional_compensation currency other_currency salary_context  \
# 0                          0.0      USD            NaN            NaN
# 2                          NaN      USD            NaN            NaN
# 3                       3000.0      USD            NaN            NaN
# 4                       7000.0      USD            NaN            NaN
# 5                          NaN      USD            NaN            NaN
# ...                        ...      ...            ...            ...
# 28052                  15000.0      USD            NaN            NaN
# 28057                      NaN      USD            NaN            NaN
# 28058                      NaN      USD            NaN            NaN
# 28059                      0.0      USD            NaN            NaN
# 28060                     10.0      USD            NaN            NaN
#
#               country           state  \
# 0       United States   Massachusetts
# 2                  US       Tennessee
# 3                 USA       Wisconsin
# 4                  US  South Carolina
# 5                 USA   New Hampshire
# ...               ...             ...
# 28052             Usa   Massachusetts
# 28057  United States         Missouri
# 28058             USA         Georgia
# 28059         Myanmar        Colorado
# 28060           Burma             NaN
#
#                                                city      total_yoe  \
# 0                                            Boston      5-7 years
# 2                                       Chattanooga    2 - 4 years
# 3                                         Milwaukee   8 - 10 years
# 4                                        Greenville   8 - 10 years
# 5                                           Hanover   8 - 10 years
# ...                                             ...            ...
# 28052  Boise-but remote. Company located in Boston    8 - 10 years
# 28057                                   Wentzville   11 - 20 years
# 28058                                       Atlanta      5-7 years
# 28059                                        Yangon    2 - 4 years
# 28060                                        Yangon    2 - 4 years
#
#             field_yoe         highest_education_completed gender  \
# 0           5-7 years                     Master's degree  Woman
# 2         2 - 4 years                      College degree  Woman
# 3           5-7 years                      College degree  Woman
# 4           5-7 years                      College degree  Woman
# 5         2 - 4 years                     Master's degree    Man
# ...               ...                                 ...    ...
# 28052    8 - 10 years                     Master's degree  Woman
# 28057   11 - 20 years  Professional degree (MD, JD, etc.)  Woman
# 28058       5-7 years                      College degree    Man
# 28059     2 - 4 years                        Some college    Man
# 28060  1 year or less                        Some college    Man
#
#                           race
# 0                        White
# 2                        White
# 3                        White
# 4                        White
# 5                        White
# ...                        ...
# 28052                    White
# 28057                    White
# 28058                    White
# 28059  Asian or Asian American
# 28060  Asian or Asian American
#
# [23374 rows x 18 columns]

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

usd.country.value_counts()
# Out:
# country
# United States     8989
# USA               7922
# US                2606
# United States      667
# U.S.               580
#                   ...
# Saudi Arabia         1
# LOUTRELAND           1
# philippines          1
# Myanmar              1
# Burma                1
# Name: count, Length: 229, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.

usd.loc[(usd['country'] == 'United States')
        | (usd['country'] == 'USA')
        | (usd['country'] == 'US')
        | (usd['country'] == 'United States ')
        | (usd['country'] == 'U.S.'), 'country'] = 'US'

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

usd.country.value_counts()
# Out:
# country
# US                          20764
# USA                           467
# Usa                           448
# United States of America      427
# United states                 208
#                             ...
# Saudi Arabia                    1
# LOUTRELAND                      1
# philippines                     1
# Myanmar                         1
# Burma                           1
# Name: count, Length: 225, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

usd['salary'].agg(['min', 'max', 'mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 3
#       1 # Find the minimum, mean, and maximum salary in USD by U.S. state.
# ----> 3 usd['salary'].agg(['min', 'max', 'mean'])
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/series.py:4777, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4774     func = dict(kwargs.items())
#    4776 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4777 result = op.agg()
#    4778 return result
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/apply.py:1425, in SeriesApply.agg(self)
#    1424 def agg(self):
# -> 1425     result = super().agg()
#    1426     if result is None:
#    1427         obj = self.obj
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)    324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/apply.py:744, in NDFrameApply.agg_or_apply_list_like(self, op_name)
#     741 if getattr(obj, "axis", 0) == 1:
#     742     raise NotImplementedError("axis other than 0 is not supported")
# --> 744 keys, results = self.compute_list_like(op_name, obj, kwargs)
#     745 result = self.wrap_results_list_like(keys, results)
#     746 return result
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/apply.py:369, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     363 colg = obj._gotitem(selected_obj.name, ndim=1, subset=selected_obj)
#     364 args = (
#     365     [self.axis, *self.args]
#     366     if include_axis(op_name, colg)
#     367     else self.args
#     368 )
# --> 369 new_res = getattr(colg, op_name)(a, *args, **kwargs)
#     370 results.append(new_res)
#     372 # make sure we find a good name
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/series.py:4777, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4774     func = dict(kwargs.items())
#    4776 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4777 result = op.agg()
#    4778 return result
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/apply.py:1425, in SeriesApply.agg(self)
#    1424 def agg(self):
# -> 1425     result = super().agg()
#    1426     if result is None:
#    1427         obj = self.obj
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/apply.py:603, in Apply.apply_str(self)
#     601         else:
#     602             self.kwargs["axis"] = self.axis
# --> 603 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/apply.py:693, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     691 f = getattr(obj, func)
#     692 if callable(f):
# --> 693     return f(*args, **kwargs)
#     695 # people may aggregate on a non-callable attribute
#     696 # but don't let them think they can pass args to it
#     697 assert len(args) == 0
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)   6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12392 nv.validate_func(name, (), kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6463     # GH#47500 - change to TypeError to match other methods
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '55,00034,00062,00060,00062,00033,00050,000112,00045,00047,50062,000100,00052,00085,00059,00098,00054,00074,00050,00096,00044,50060,00062,00048,000140,00080,00039,000125,000230,000110,00050,00068,00041,00076,00078,00037,000100,00065,000187,500110,00066,625144,600200,85096,00053,00095,00072,000106,000115,000100,50033,20052,000104,00052,00070,00084,00053,00034,00038,00087,000122,00045,00088,00071,00071,00075,00080,000125,00065,00055,00090,000105,00065,00085,00039,52076,000180,00090,00065,00098,16663,5005847,70087,00039,63553,00047,255196,00034,361150,00075,00020,000107,22095,00042,000100,000119,00075,000145,00048,00075,00042,00054,00060,000101,50036,88385,00062,000130,00055,00059,01571,00053,00063,00095,00035,00033,28056,00085,00062,00074,00063,00086,00042,000114,00073,000100,00060,129135,000130,00026,00060,00037,00085,00045,00092,00065,00035,00074,000102,500117,50070,000140,00058,000400,00061,20066,00070,00052,00075,50057,00083,20077,50031,200215,00055,000220,000100,00080,00063,00052,50094,00057,00083,00090,00066,95076,00070,00060,00080,00070,00034,29950,00085,00087,000125,00055,000275,00048,500139,00054,080170,00070,00053,00082,16071,00025,700105,00077,00050,00031,61695,00062,00075,00071,00088,00031,50076,000165,00045,76086,00056,00067,000125,00055,000125,00060,000190,00060,320125,00094,00049,000120,00028,000135,00040,57575,500115,00070,000110,00029,00061,00047,25096,00045,00072,00078,167132,500124,000108,000110,00083,000110,00045,00091,000117,00059,00071,69790,000120,00052,00080,00056,00047,840150,000150,000105,000100,00097,500100,000125,00063,00079,00052,000109,000120,00070,000110,00045,00070,000115,00017,00064,00066,00080,00078,00065,000110,000114,400111,50058,300700,000156,000130,00075,000126,000125,00038,48036,00055,00053,50049,60050,00057,75062,00065,00043,680103,00065,00075,00072,50086,00075,00038,00063,00039,000105,00053,000179,00077,00055,00064,20043,50092,000170,00087,938125,000186,00051,00061,800155,00040,00071,75070,00087,000157,00065,00042,12065,00085,00086,00085,00094,000104,00088,00052,00065,000175,000134,00098,50043,00036,712112,00085,00060,00050,00052,00057,00051,00054,00056,00056,00039,00040,00068,00065,00067,000126,00075,00050,000146,000100,00052,000135,000131,00064,00061,80049,00038,80050,00070,000126,000107,00031,50080,000600,000105,000120,00082,00090,00065,00080,00060,000180,000157,029120,00082,00083,50044,50058,240107,500155,00082,40065,00082,50034,00045,000140,000201,000210,000115,00080,00058,800101,360103,000170,00080,00066,80590,000117,00045,00054,00033,28036,00058,000165,000102,000136,000110,00072,10075,00037,02455,00078,00050,000145,000100,00064,80070,60065,00075,00075,00040,00047,84092,000165,00039,91753,00059,40054,07553,89576,00067,080115,00072,00071,40064,00053,00072,000120,000103,500139,00038,11090,00053,000117,000100,00052,00040,00032,00060,50087,00095,00089,00070,00072,00078,40050,00090,00073,00090,00070,000118,00080,000153,000107,000119,00040,00066,90058,00060,00065,00052,00085,000140,00053,00042,00080,00044,77795,00040,000150,00037,000110,40070,000200,00069,00094,25740,00089,00072,30082,00065,00036,000105,000117,000126,000107,00055,00051,000108,00040,000170,00065,00075,00091,00044,00052,000111,43358,32758,00056,000144,00066,84091,00087,00035,14025,000120,000154,00037,96050,00080,00051,00067,15085,00053,00082,50058,000200,000110,00058,00071,50080,000109,00052,00037,44054,000142,33575,00093,00023,00051,00072,00037,419100,00062,000105,00094,00091,00052,80065,000110,00087,55082,00055,00040,00046,00038,60057,500127,50093,60066,91378,28086,00065,00087,36037,00081,00058,500241,00070,00068,24574,00075,00056,50053,04065,818133,54039,50080,00070,00083,50060,00033,28063,00066,00089,02478,00042,00054,00044,00050,00083,20066,00072,00075,00085,000113,00060,80062,00033,80063,00049,52467,000176,50055,000113,000105,00084,00060,00081,20052,520115,000160,000120,00081,00060,000253,30066,250124,000115,00054,00090,00049,00071,309130,00062,00067,67526,000101,00077,000222,00064, ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.

usd['salary'] = pd.to_numeric(usd['salary'])

usd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "55,000"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 3
#       1 # Fix it.
# ----> 3 usd['salary'] = pd.to_numeric(usd['salary'])
#       5 usd
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/tools/numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233 coerce_numeric = errors not in ("ignore", "raise")
#     234 try:
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
#     237         set(),
#     238         coerce_numeric=coerce_numeric,
#     239         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     240         or isinstance(values_dtype, StringDtype)
#     241         and values_dtype.na_value is libmissing.NA,
#     242     )
#     243 except (ValueError, TypeError):
#     244     if errors == "raise":
#
# File pandas/_libs/lib.pyx:2449, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "55,000" at position 0

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

usd = usd.replace(',', '', regex=True)

usd['salary'] = pd.to_numeric(usd['salary'])

usd['salary'].agg(['min', 'max', 'mean'])
# Out:
# min     0.000000e+00
# max     1.020000e+08
# mean    9.635113e+04
# Name: salary, dtype: float64

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
usd['timestamp'] = pd.to_datetime(usd['timestamp'])
twenty_one = usd['timestamp'].dt.year == 2021
twenty_two = usd['timestamp'].dt.year == 2022
twenty_three = usd['timestamp'].dt.year == 2023

usd = usd[twenty_one | twenty_two | twenty_three]

usd
# Out:
#                 timestamp    age  \
# 0     2021-04-27 11:02:10  25-34
# 2     2021-04-27 11:02:38  25-34
# 3     2021-04-27 11:02:41  25-34
# 4     2021-04-27 11:02:42  25-34
# 5     2021-04-27 11:02:46  25-34
# ...                   ...    ...
# 27994 2023-11-20 14:57:55  35-44
# 27995 2023-11-26 17:38:00  18-24
# 27996 2023-11-29 19:59:34  18-24
# 27998 2023-12-04 16:21:22  35-44
# 27999 2023-12-26 10:37:17  45-54
#
#                                            industry  \
# 0                      Education (Higher Education)
# 2                      Accounting Banking & Finance
# 3                                        Nonprofits
# 4                      Accounting Banking & Finance
# 5                      Education (Higher Education)
# ...                                             ...
# 27994                               Media & Digital
# 27995                  Education (Higher Education)
# 27996  I'm currently a student and don't have a job
# 27998                              Public Libraries
# 27999                                 Entertainment
#
#                                     title                      title_context  \
# 0      Research and Instruction Librarian                                NaN
# 2                    Marketing Specialist                                NaN
# 3                         Program Manager                                NaN
# 4                      Accounting Manager                                NaN
# 5          Scholarly Publishing Librarian                                NaN
# ...                                   ...                                ...
# 27994                        Media Buyer   Freelance for online advertising
# 27995                                  TA                                NaN
# 27996                                 NaN         I don't have one right now
# 27998            Youth Services Librarian                                NaN
# 27999            Financial System Analyst                                NaN
#
#        salary  additional_compensation currency other_currency  \
# 0       55000                      0.0      USD            NaN
# 2       34000                      NaN      USD            NaN
# 3       62000                   3000.0      USD            NaN
# 4       60000                   7000.0      USD            NaN
# 5       62000                      NaN      USD            NaN
# ...       ...                      ...      ...            ...
# 27994  156000                      NaN      USD            NaN
# 27995   12000                      NaN      USD            NaN
# 27996       0                      0.0      USD            NaN
# 27998   80000                      NaN      USD            NaN
# 27999  105000                      0.0      USD            NaN
#
#                      salary_context country           state         city  \
# 0                               NaN      US   Massachusetts       Boston
# 2                               NaN      US       Tennessee  Chattanooga
# 3                               NaN      US       Wisconsin    Milwaukee
# 4                               NaN      US  South Carolina   Greenville
# 5                               NaN      US   New Hampshire      Hanover
# ...                             ...     ...             ...          ...
# 27994                           NaN      US      California  Los Angeles
# 27995                           NaN      US           Texas       denton
# 27996  There is no income right now   U.S.A    Pennsylvania          NaN
# 27998                           NaN      US       Minnesota  Minneapolis
# 27999                           NaN      US        New York          NYC
#
#            total_yoe       field_yoe highest_education_completed  \
# 0          5-7 years       5-7 years             Master's degree
# 2        2 - 4 years     2 - 4 years              College degree
# 3       8 - 10 years       5-7 years              College degree
# 4       8 - 10 years       5-7 years              College degree
# 5       8 - 10 years     2 - 4 years             Master's degree
# ...              ...             ...                         ...
# 27994  11 - 20 years    8 - 10 years              College degree
# 27995    2 - 4 years  1 year or less             Master's degree
# 27996    2 - 4 years     2 - 4 years                Some college
# 27998  11 - 20 years    8 - 10 years             Master's degree
# 27999  11 - 20 years    8 - 10 years              College degree
#
#                               gender                               race
# 0                              Woman                              White
# 2                              Woman                              White
# 3                              Woman                              White
# 4                              Woman                              White
# 5                                Man                              White
# ...                              ...                                ...
# 27994                          Woman                              White
# 27995  Other or prefer not to answer          Black or African American
# 27996                            Man          Black or African American
# 27998                          Woman                              White
# 27999                          Woman  Hispanic Latino or Spanish origin
#
# [23328 rows x 18 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
