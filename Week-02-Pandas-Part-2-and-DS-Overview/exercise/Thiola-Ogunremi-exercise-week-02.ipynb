# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.

import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).
food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
food_count = df_food.shape[0]
print('size of rows in food data file ', food_count)
# Out:
# size of rows in food data file  125
# size of row in ask a manager file  28062

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.

df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
cols_to_select = ['calories_day','weight','Gender']
new_df_food = df_food[cols_to_select]
new_df_food.head()
# Out:
#    calories_day                    weight  Gender
# 0           NaN                       187       2
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

new_df_food.isnull().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.

new_df_food2 = new_df_food.dropna()
new_df_food2.isnull().sum()
new_df_food2.head()
# Out:
#    calories_day                    weight  Gender
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1
# 5           3.0                       190       1

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.

new_df_food2.head()
# Check which are numeric
# used ai to help with this
#pd.to_numeric converts a string to numbers then errors='coerce' forces string to be nan if not numbers
#np.nan is null for numbers what nan is for objects
# is_numeric will become a select cond
is_numeric = pd.to_numeric(new_df_food2['weight'], errors='coerce').notna()
new_df_food3 = new_df_food2[is_numeric].copy()
new_df_food3.head()
# Out:
#    calories_day weight  Gender
# 1           3.0    155       1
# 4           2.0    190       1
# 5           3.0    190       1
# 6           3.0    180       2
# 7           3.0    137       1

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
new_df_food3.to_csv('/workspaces/ds-fall-2025-tue/Week-02-Pandas-Part-2-and-DS-Overview/data/new_food_coded.csv')

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).

# to read the tsv file, open the file and do ctrl + a the
df_manager = pd.read_csv('/workspaces/ds-fall-2025-tue/Week-02-Pandas-Part-2-and-DS-Overview/data/ask_manager_salary_survey.tsv', sep='\t')
df_manager
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# ...

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.

manager_count = df_manager.shape[0]
print('size of row in ask a manager file ', manager_count)
# Out:
# size of row in ask a manager file  28062

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_manager.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                             28062 non-null  object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Strip spaces and newlines to rename better
df_manager.columns = df_manager.columns.str.strip()

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
# df.rename(columns={"A": "a", "B": "c"})
df_manager.rename(columns={"Timestamp":"timestamp", "How old are you?":"age" , "What industry do you work in?":"industry", "Job title":"title", "If your job title needs additional context, please clarify here:":"title_context", "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)":"salary","How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits." :"additional_compensation", "Please indicate the currency":"currency", 'If "Other," please indicate the currency here:':"other_currency","If your income needs additional context, please provide it here:": "salary_context", "What country do you work in?":"country", "If you're in the U.S., what state do you work in?":"state","What city do you work in?":"city","How many years of professional work experience do you have overall?" :"total_yoe", "How many years of professional work experience do you have in your field?": "field_yoe", "What is your highest level of education completed?":"highest_education_completed","What is your gender?" :"gender", "What is your race? (Choose all that apply.)": "race"})
#w
df_manager.columns = ["timestamp", "age" , "industry", "title", "title_context", "salary","additional_compensation", "currency", "other_currency", "salary_context","country", "state","city","total_yoe", "field_yoe", "highest_education_completed","gender", "race"]
#w
df_manager
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                    Health care
#
#                                           title title_context   salary  \
# 0            Research and Instruction Librarian           NaN   55,000
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_manager.columns = df_manager.columns.str.strip()
grouped = df_manager.groupby(['industry']).size()
grouped.reset_index()
# Out:
#                           industry  0
# 0                            Buyer  1
# 1              Veterinary medicine  1
# 2                         Academia  4
# 3                        Academia   1
# 4                  Academia - STEM  1
# ...                            ... ..
# 1214  trade association/membership  1
# 1215                   translation  1
# 1216            veterinary biotech  1
# 1217                   video games  1
# 1218        wholesale distribution  3
#
# [1219 rows x 2 columns]

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
df_manager_sort = grouped.sort_values()
df_manager_sort.tail()
# Out:
# industry
# Government and Public Administration    1889
# Health care                             1896
# Nonprofits                              2419
# Education (Higher Education)            2464
# Computing or Tech                       4699
# dtype: int64

# %%
industry_list = ["Government and Public Administration","Health care","Nonprofits", "Education (Higher Education)","Computing or Tech"]
industry = 'What industry do you work in?'
cond = df_manager.industry.isin(industry_list)
df_salary_tech = df_manager[cond]
df_salary_tech
# Out:
#                 timestamp    age                      industry  \
# 0      4/27/2021 11:02:10  25-34  Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34             Computing or Tech
# 3      4/27/2021 11:02:41  25-34                    Nonprofits
# 5      4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8      4/27/2021 11:03:01  45-54             Computing or Tech
# ...                   ...    ...                           ...
# 28053  7/12/2024 18:23:10  18-24                    Nonprofits
# 28057  7/12/2024 22:52:01  35-44                   Health care
# 28058  7/23/2024 17:51:03  25-34             Computing or Tech
# 28060  7/26/2024 11:20:45  18-24             Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                   Health care
#
#                                           title                 title_context  \
# 0            Research and Instruction Librarian                           NaN
# ...

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 


sanity_check_groupby = df_salary_tech.groupby(['industry']).size()
sanity_check_groupby
# Out:
# industry
# Computing or Tech                       4699
# Education (Higher Education)            2464
# Government and Public Administration    1889
# Health care                             1896
# Nonprofits                              2419
# dtype: int64

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!

cond_dollars = df_salary_tech['currency'] == 'USD'
print("Numbers of workers paid in USD:", df_salary_tech[cond_dollars].shape[0])
df_USD = df_salary_tech[cond_dollars]
#df_salary_tech.head()
df_USD.head()
# Out:
# Numbers of workers paid in USD: 11084
#              timestamp    age                      industry  \
# 0   4/27/2021 11:02:10  25-34  Education (Higher Education)
# 3   4/27/2021 11:02:41  25-34                    Nonprofits
# 5   4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8   4/27/2021 11:03:01  45-54             Computing or Tech
# 10  4/27/2021 11:03:03  25-34                    Nonprofits
#
#                                  title                 title_context   salary  \
# 0   Research and Instruction Librarian                           NaN   55,000
# 3                      Program Manager                           NaN   62,000
# 5       Scholarly Publishing Librarian                           NaN   62,000
# 8                      Systems Analyst  Data developer/ETL Developer  112,000
# 10                      Office Manager                           NaN   47,500
#
#     additional_compensation currency other_currency salary_context  \
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_USD.groupby(['country']).size().sort_values(ascending=False)
# Out:
# country
# United States     4318
# USA               3813
# US                1252
# U.S.               292
# United States      255
#                   ...
# denmark              1
# united stated        1
# uS                   1
# u.s.                 1
# 🇺🇸                   1
# Length: 139, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.

df_USD['country'].replace('United States', 'US', inplace=True)
df_USD['country'].replace('USA', 'US', inplace=True)
df_USD['country'].replace('U.S.', 'US', inplace=True)
df_USD['country'].replace('United States ', 'US', inplace=True)
# Out:
# /tmp/ipykernel_2328/3711745124.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_USD['country'].replace('United States', 'US', inplace=True)
# /tmp/ipykernel_2328/3711745124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_USD['country'].replace('United States', 'US', inplace=True)
# ...

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

df_USD.groupby(['country']).size().sort_values(ascending=False)
# Out:
# country
# US                          9930
# United States of America     222
# USA                          195
# Usa                          178
# usa                           81
#                             ...
# denmark                        1
# united stated                  1
# uS                             1
# u.s.                           1
# 🇺🇸                             1
# Length: 135, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

df_USD['country'] = df_USD['country'].str.replace('usa', 'US', case=False, regex=True)
df_USD['country'] = df_USD['country'].str.replace('United State', 'US', case=False, regex=True)
df_USD['country'] = df_USD['country'].str.replace('us ', 'US', case=False, regex=True)
# Out:
# /tmp/ipykernel_2328/1961245795.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_USD['country'] = df_USD['country'].str.replace('usa', 'US', case=False, regex=True)
# /tmp/ipykernel_2328/1961245795.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_USD['country'] = df_USD['country'].str.replace('United State', 'US', case=False, regex=True)
# /tmp/ipykernel_2328/1961245795.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

df_USD.groupby(['country']).size().sort_values(ascending=False)
# Out:
# country
# US                10415
# USs of America      222
# USs                 128
# Us                   39
# us                   21
#                   ...
# pakistan              1
# ss                    1
# u.s.                  1
# uS                    1
# 🇺🇸                    1
# Length: 120, dtype: int64

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

df_USD.groupby(['country', 'state']).agg({'salary': ['min','mean','max']})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
df_USD['salary'] = pd.to_numeric(df_USD['salary'].str.replace(',', ''), errors='coerce')
# Out:
# /tmp/ipykernel_2328/4016640779.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_USD['salary'] = pd.to_numeric(df_USD['salary'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

grouped_state = df_USD.groupby(['state']).agg({'salary': ['min','mean','max']})
grouped_state.reset_index()
# Out:
#                             state  salary
#                                       min           mean     max
# 0                         Alabama   15000   74809.456522  350000
# 1   Alabama, District of Columbia  156000  156000.000000  156000
# 2                 Alabama, Kansas   64197   64197.000000   64197
# 3                Alabama, Montana   72000   72000.000000   72000
# 4                 Alabama, Oregon   50000   50000.000000   50000
# ..                            ...     ...            ...     ...
# 76                       Virginia   24000  100371.276882  700000
# 77                     Washington      72  119582.932258  950000
# 78                  West Virginia   27000   64054.545455  125000
# 79                      Wisconsin       1   79108.346457  920000
# 80                        Wyoming   45000   66469.666667  140000
#
# [81 rows x 4 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

df_USD['timestamp'] = pd.to_datetime(df_USD['timestamp'] )
df_USD.head()
df_date = df_USD[(df_USD['timestamp'].dt.year >= 2021) & (df_USD['timestamp'].dt.year <= 2023)]
df_date
# Out:
# /tmp/ipykernel_2328/1337690266.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_USD['timestamp'] = pd.to_datetime(df_USD['timestamp'] )
#                 timestamp    age                              industry  \
# 0     2021-04-27 11:02:10  25-34          Education (Higher Education)
# 3     2021-04-27 11:02:41  25-34                            Nonprofits
# 5     2021-04-27 11:02:46  25-34          Education (Higher Education)
# 8     2021-04-27 11:03:01  45-54                     Computing or Tech
# 10    2021-04-27 11:03:03  25-34                            Nonprofits
# ...                   ...    ...                                   ...
# 27974 2023-09-04 03:24:31  25-34          Education (Higher Education)
# ...

# %%
grouped_date = df_date.groupby(['state']).agg({'salary': ['min','mean','max']})
grouped_date.reset_index()
# Out:
#                             state  salary
#                                       min           mean     max
# 0                         Alabama   15000   75649.636364  350000
# 1   Alabama, District of Columbia  156000  156000.000000  156000
# 2                 Alabama, Kansas   64197   64197.000000   64197
# 3                Alabama, Montana   72000   72000.000000   72000
# 4                 Alabama, Oregon   50000   50000.000000   50000
# ..                            ...     ...            ...     ...
# 76                       Virginia   24000  100371.276882  700000
# 77                     Washington      72  119612.710824  950000
# 78                  West Virginia   27000   64054.545455  125000
# 79                      Wisconsin       1   79108.346457  920000
# 80                        Wyoming   45000   66469.666667  140000
#
# [81 rows x 4 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
