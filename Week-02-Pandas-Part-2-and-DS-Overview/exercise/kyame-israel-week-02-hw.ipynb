# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
print( f"Amount of Data: {len(df_food)}")
# Out:
# Amount of Data: 125

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
print(df_food.dtypes.to_dict())
# Out:
# {'GPA': dtype('O'), 'Gender': dtype('int64'), 'breakfast': dtype('int64'), 'calories_chicken': dtype('int64'), 'calories_day': dtype('float64'), 'calories_scone': dtype('float64'), 'coffee': dtype('int64'), 'comfort_food': dtype('O'), 'comfort_food_reasons': dtype('O'), 'comfort_food_reasons_coded': dtype('float64'), 'cook': dtype('float64'), 'comfort_food_reasons_coded.1': dtype('int64'), 'cuisine': dtype('float64'), 'diet_current': dtype('O'), 'diet_current_coded': dtype('int64'), 'drink': dtype('float64'), 'eating_changes': dtype('O'), 'eating_changes_coded': dtype('int64'), 'eating_changes_coded1': dtype('int64'), 'eating_out': dtype('int64'), 'employment': dtype('float64'), 'ethnic_food': dtype('int64'), 'exercise': dtype('float64'), 'father_education': dtype('float64'), 'father_profession': dtype('O'), 'fav_cuisine': dtype('O'), 'fav_cuisine_coded': dtype('int64'), 'fav_food': dtype('float64'), 'food_childhood': dtype('O'), 'fries': dtype('int64'), 'fruit_day': dtype('int64'), 
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
focus_group = ['calories_day', 'weight', 'Gender']
df_food_focus = df_food[focus_group]

df_food_focus
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
df_food_focus.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_food_focus = df_food_focus.dropna()
df_food_focus
# Out:
#      calories_day                    weight  Gender
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# 5             3.0                       190       1
# ..            ...                       ...     ...
# 118           3.0                       140       1
# 119           3.0                       185       2
# 120           4.0                       156       1
# 121           2.0                       180       1
# 123           4.0                       135       2
#
# [104 rows x 3 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
df_food_focus['weight'] = pd.to_numeric(df_food_focus['weight'], errors='coerce')
df_food_focus = df_food_focus.dropna().copy()

df_food_focus
# Out:
# /tmp/ipykernel_1839/3297087061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food_focus['weight'] = pd.to_numeric(df_food_focus['weight'], errors='coerce')
#      calories_day  weight  Gender
# 1             3.0   155.0       1
# 4             2.0   190.0       1
# 5             3.0   190.0       1
# 6             3.0   180.0       2
# 7             3.0   137.0       1
# ..            ...     ...     ...
# 118           3.0   140.0       1
# 119           3.0   185.0       2
# 120           4.0   156.0       1
# 121           2.0   180.0       1
# 123           4.0   135.0       2
#
# [101 rows x 3 columns]

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
save_as = 'new_food_code.csv'

df_food_focus.to_csv(save_as, index=False)

with open(save_as, 'rt') as text_file:
    for line in text_file.readlines():
        print(line)
# Out:
# calories_day,weight,Gender
#
# 3.0,155.0,1
#
# 2.0,190.0,1
#
# 3.0,190.0,1
#
# 3.0,180.0,2
#
# 3.0,137.0,1
#
# 3.0,125.0,1
#
# 3.0,116.0,1
#
# 4.0,110.0,1
#
# 3.0,264.0,2
#
# 3.0,123.0,1
#
# 3.0,185.0,2
#
# 3.0,145.0,1
#
# 3.0,170.0,2
#
# 3.0,135.0,1
#
# 2.0,165.0,2
#
# 3.0,175.0,2
#
# 3.0,195.0,2
#
# 3.0,185.0,2
#
# 3.0,185.0,2
#
# 2.0,105.0,1
#
# 3.0,125.0,1
#
# 2.0,160.0,2
#
# 4.0,175.0,2
#
# 2.0,180.0,2
#
# 2.0,167.0,2
#
# 3.0,115.0,1
#
# 3.0,205.0,2
#
# 3.0,128.0,1
#
# 3.0,150.0,1
#
# 2.0,150.0,1
#
# 3.0,150.0,1
#
# 4.0,170.0,1
#
# 3.0,150.0,1
#
# 3.0,140.0,2
#
# 4.0,120.0,1
#
# 3.0,135.0,1
#
# 2.0,100.0,1
#
# 4.0,170.0,1
#
# 3.0,113.0,1
#
# 2.0,168.0,2
#
# 3.0,150.0,2
#
# 3.0,169.0,2
#
# 4.0,185.0,2
#
# 4.0,200.0,2
#
# 3.0,165.0,2
#
# 2.0,192.0,1
#
# 4.0,175.0,2
#
# 4.0,140.0,1
#
# 3.0,155.0,1
#
# 4.0,135.0,1
#
# 2.0,118.0,1
#
# 4.0,210.0,2
#
# 4.0,180.0,1
#
# 3.0,140.0,1
#
# 3.0,125.0,1
#
# 3.0,145.0,1
#
# 4.0,130.0,1
#
# 3.0,140.0,1
#
# 3.0,140.0,2
#
# 4.0,200.0,2
#
# ...

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
df_salary = pd.read_csv('../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', sep='\t')
df_salary
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
# ----> 2 df_salary = pd.read_csv('../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', sep='\t')
#       3 df_salary
#
# ...

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %%
os.rename('../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', 
          '../data/salary_survey'
          )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 os.rename('../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv',
#       2           '../data/salary_survey'
#       3           )
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv' -> '../data/salary_survey'

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
df_salary = pd.read_csv('../data/salary_survey', sep='\t')
df_salary
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# ...

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
print(df_salary.dtypes.to_dict())
# Out:
# {'Timestamp': dtype('O'), 'How old are you?': dtype('O'), 'What industry do you work in?': dtype('O'), 'Job title': dtype('O'), 'If your job title needs additional context, please clarify here:': dtype('O'), "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)": dtype('O'), 'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.': dtype('float64'), 'Please indicate the currency': dtype('O'), 'If "Other," please indicate the currency here: ': dtype('O'), 'If your income needs additional context, please provide it here:': dtype('O'), 'What country do you work in?': dtype('O'), "If you're in the U.S., what state do you work in?": dtype('O'), 'What city do you work in?': dtype('O'
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
df_salary.columns = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed', 'gender', 'race']
df_salary
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                    Health care
#
#                                           title title_context   salary  \
# 0            Research and Instruction Librarian           NaN   55,000
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary['industry'].value_counts()
# Out:
# industry
# Computing or Tech                        4699
# Education (Higher Education)             2464
# Nonprofits                               2419
# Health care                              1896
# Government and Public Administration     1889
#                                          ...
# Warehousing                                 1
# Education (Early Childhood Education)       1
# SAAS                                        1
# Health and Safety                           1
# Aerospace Manufacturing                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
top_five = ['Computing or Tech', 'Education (Higher Education)', 'Nonprofits', 'Health care', 'Government and Public Administration']
new_industry = df_salary.industry.isin(top_five)
df_salary_tech = df_salary[new_industry]

df_salary_tech
# Out:
#                 timestamp    age                      industry  \
# 0      4/27/2021 11:02:10  25-34  Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34             Computing or Tech
# 3      4/27/2021 11:02:41  25-34                    Nonprofits
# 5      4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8      4/27/2021 11:03:01  45-54             Computing or Tech
# ...                   ...    ...                           ...
# 28053  7/12/2024 18:23:10  18-24                    Nonprofits
# 28057  7/12/2024 22:52:01  35-44                   Health care
# 28058  7/23/2024 17:51:03  25-34             Computing or Tech
# 28060  7/26/2024 11:20:45  18-24             Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                   Health care
#
#                                           title                 title_context  \
# 0            Research and Instruction Librarian                           NaN
# ...

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 
df_salary_tech['industry'].value_counts()
# Out:
# industry
# Computing or Tech                       4699
# Education (Higher Education)            2464
# Nonprofits                              2419
# Health care                             1896
# Government and Public Administration    1889
# Name: count, dtype: int64

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
money = ['USD']
find_money = df_salary_tech.currency.isin(money)
df_salary_tech = df_salary_tech[find_money]

df_salary_tech
# Out:
#                 timestamp    age                      industry  \
# 0      4/27/2021 11:02:10  25-34  Education (Higher Education)
# 3      4/27/2021 11:02:41  25-34                    Nonprofits
# 5      4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8      4/27/2021 11:03:01  45-54             Computing or Tech
# 10     4/27/2021 11:03:03  25-34                    Nonprofits
# ...                   ...    ...                           ...
# 28051   7/1/2024 20:05:58  25-34             Computing or Tech
# 28052   7/3/2024 14:02:01  25-34             Computing or Tech
# 28057  7/12/2024 22:52:01  35-44                   Health care
# 28058  7/23/2024 17:51:03  25-34             Computing or Tech
# 28060  7/26/2024 11:20:45  18-24             Computing or Tech
#
#                                         title                 title_context  \
# 0          Research and Instruction Librarian                           NaN
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_tech['country'].value_counts()
# Out:
# country
# United States     4318
# USA               3813
# US                1252
# U.S.               292
# United States      255
#                   ...
# Nigeria              1
# ss                   1
# Nigeria              1
# Chile                1
# Burma                1
# Name: count, Length: 139, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
america = ['United States', 'United States ', 'USA', 'US', 'U.S.']

df_salary_tech['country'] = df_salary_tech['country'].replace(america, 'US')
# Out:
# /tmp/ipykernel_1839/2792970379.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech['country'] = df_salary_tech['country'].replace(america, 'US')

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_tech['country'].value_counts()
# Out:
# country
# US                          9930
# United States of America     222
# USA                          195
# Usa                          178
# usa                           81
#                             ...
# Nigeria                        1
# ss                             1
# Nigeria                        1
# Chile                          1
# Burma                          1
# Name: count, Length: 135, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
df_salary_tech.groupby('state')['salary'].agg(['min', 'mean', 'max'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
df_salary_tech['salary'] = pd.to_numeric(df_salary_tech['salary'], errors='coerce')
# Out:
# /tmp/ipykernel_1839/1800991916.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech['salary'] = pd.to_numeric(df_salary_tech['salary'], errors='coerce')

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
df_salary_tech.groupby('state')['salary'].agg(['min', 'mean', 'max'])
# Out:
#                                    min           mean       max
# state
# Alabama                        22800.0   90962.400000  350000.0
# Alabama, District of Columbia      NaN            NaN       NaN
# Alabama, Kansas                    NaN            NaN       NaN
# Alabama, Montana                   NaN            NaN       NaN
# Alabama, Oregon                50000.0   50000.000000   50000.0
# ...                                ...            ...       ...
# Virginia                       25000.0   97474.939394  378000.0
# Washington                        72.0  107722.678082  300000.0
# West Virginia                  71000.0   95500.000000  120000.0
# Wisconsin                          1.0   94330.823529  920000.0
# Wyoming                        50004.0   54606.000000   63686.0
#
# [81 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
df_salary_tech['timestamp'] = pd.to_datetime(df_salary_tech['timestamp'])
df_salary_recent = df_salary_tech[df_salary_tech.timestamp.dt.year.isin([2021, 2022, 2023])]

df_salary_recent.groupby('state')['salary'].agg(['min', 'mean', 'max'])
# Out:
#                                    min           mean       max
# state
# Alabama                        22800.0   90962.400000  350000.0
# Alabama, District of Columbia      NaN            NaN       NaN
# Alabama, Kansas                    NaN            NaN       NaN
# Alabama, Montana                   NaN            NaN       NaN
# Alabama, Oregon                50000.0   50000.000000   50000.0
# ...                                ...            ...       ...
# Virginia                       25000.0   97474.939394  378000.0
# Washington                        72.0  107722.678082  300000.0
# West Virginia                  71000.0   95500.000000  120000.0
# Wisconsin                          1.0   94330.823529  920000.0
# Wyoming                        50004.0   54606.000000   63686.0
#
# [81 rows x 3 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
